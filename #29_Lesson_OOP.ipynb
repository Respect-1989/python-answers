# %%
class Talaba:
    def __init__(self,name,sec_name,b_year):
        self.name=name
        self.sec_name=sec_name
        self.b_year=b_year
        self.kurs=2
    
    def get_name(self):
        return self.name
    
    def get_sec_name(self):
        return self.sec_name
    
    def get_age(self,year):
        return year-self.b_year
    
    def set_bosqich(self,yangi_kurs):
        self.kurs=yangi_kurs
        #return yangi_kurs
    
    def update_bosqich(self):
        self.kurs+=1
        
    def get_info(self):
        return f"{self.name} {self.sec_name}. {self.kurs} - kurs talabasi"
    
talaba1=Talaba('Dilshod','Atadjanov',1989)
talaba2=Talaba('Anvar','Atadjanov',1980)
talaba3=Talaba('Alisher','Atadjanov',1983)
#print(talaba1.name, " ",talaba1.kurs,"- kursda uqiydi")
#print(f'Ismi:{talaba1.get_name()} yoshi:{talaba1.get_age(2022)} da')

# %%
class Fan():
    def __init__(self,nomi):
        self.nomi=nomi
        self.talabalar_son=0
        self.talabalar=[]
        
    def add_student(self,talaba):
        self.talabalar.append(talaba)
        self.talabalar_son+=1
        
    def get_student(self):
        return [x.get_info() for x in self.talabalar]
    
def see_methods(klass):
    return [method for method in dir(klass) if method.startswith('__')]
    
matem=Fan("oliy matematika")
matem.nomi                   #oliy matematika
matem.add_student(talaba1)   #add
matem.add_student(talaba2)   #add
matem.add_student(talaba3)   #add
print(matem.talabalar_son)   # 3
print(matem.nomi)            #oliy matematika
matem.talabalar[0].name      #'Dilshod'
matem.talabalar[1].get_info()#['Dilshod Atadjanov. 2 - kurs talabasi',
                             #'Anvar Atadjanov. 2 - kurs talabasi',
                             #'Alisher Atadjanov. 2 - kurs talabasi']
matem.get_student()
see_methods(Talaba)#['__class__',
                    #'__delattr__',
                    #'__dict__',
                    #'__dir__',
                    #'__doc__',
                    #'__eq__',
                    #'__format__',
                    #'__ge__',
                    #'__getattribute__',
                    #'__gt__',
                    #'__hash__',
                    #'__init__',
                    #'__init_subclass__',
                    #'__le__',
                    #'__lt__',
                    #'__module__',
                    #'__ne__',
                    #'__new__',
                    #'__reduce__',
                    #'__reduce_ex__',
                    #'__repr__',
                    #'__setattr__',
                    #'__sizeof__',
                    #'__str__',
                    #'__subclasshook__',
                    #'__weakref__']
talaba1.__dict__    #{'name': 'Dilshod', 'sec_name': 'Atadjanov', 'b_year': 1989, 'kurs': 2}
talaba1.__dict__.keys() #dict_keys(['name', 'sec_name', 'b_year', 'kurs'])
see_methods(talaba1) #['__class__',
                        '__delattr__',
                        '__dict__',
                        '__dir__',
                        '__doc__',
                        '__eq__',
                        '__format__',
                        '__ge__',
                        '__getattribute__',
                        '__gt__',
                        '__hash__',
                        '__init__',
                        '__init_subclass__',
                        '__le__',
                        '__lt__',
                        '__module__',
                        '__ne__',
                        '__new__',
                        '__reduce__',
                        '__reduce_ex__',
                        '__repr__',
                        '__setattr__',
                        '__sizeof__',
                        '__str__',
                        '__subclasshook__',
                        '__weakref__']
​
# Out:
# 3
# oliy matematika
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']
