"алаҳлаш",
"албан",
"албат",
"албатта",
"алвасти",
"алвидо",
"алвир-шалвир",
"алвон",
"алвон-алвон",
"алгебра",
"алгебраик",
"алгоритм",
"алгорифм",
"алдаб-сулдаб",
"алдам-қалдам",
"алдамоқ",
"алдамчи",
"алдамчилик",
"алдоқчи",
"алдоқчилик",
"алебастр",
"алеут",
"алжимоқ",
"алжирамоқ",
"али",
"али",
"алиби",
"ализарин",
"алик",
"алимент",
"алиф",
"алифбе",
"алифбо",
"алифламоқ",
"алифмой",
"алиш",
"алишинмоқ",
"алишмоқ",
"алкалоид",
"алкалоидлар",
"алкаш",
"алкимё",
"алкоголизм",
"алкоголик",
"алкоголь",
"алла",
"алла-палла",
"аллавақт",
"аллаким",
"аллаламоқ",
"алламаҳал",
"алламаҳалгача",
"алланарса",
"алланеча",
"алланечук",
"алланима",
"аллақаер",
"аллақаерда",
"аллақаерга",
"аллақайси",
"аллақандай",
"аллақанча",
"аллақачон",
"аллегорик",
"аллегория",
"аллерген",
"аллергик",
"аллергия",
"аллергологик",
"аллергология",
"аллигатор",
"аллитерация",
"алло",
"аллома",
"аллоф",
"аллоҳ",
"алманах",
"алмашинмоқ",
"алмашинув",
"алмашламоқ",
"алмашмоқ",
"алмаштирмоқ",
"алмисоқ"]

# %%
import random
def display_word(words):
    word=random.choice(words)
    while '-' in word or '' in word:
        word=random.choice(words)
    return word

def display(user_letter,word):
    display_word=""
    for letter in word:
        if letter in user_letter:
            display_word+=letter
        else:
            display_word+='-'
    return display_word

def play():
    word=display_word(words)
    display_letter=set(word)
    user_letter=""
    print(word)
    print(f'Men {len(word)} хоналик су\'з уйладим топа оласизми?')
    while display_letter:
        print(display(user_letter,word))
        if user_letter:
            print(f'Шу вактгача топган харфларингиз {user_letter}')
        letter=input(">>>")
        if letter in user_letter:
            print('Bunday harf avval kiritilgan!')            
        elif letter in display_letter:
            display_letter.remove(letter)
            print('Bunday harf bor')
        else:
            print('Bunday harf mavjud emas!')        
        user_letter+=letter
    print(f'Табриклайман сиз {word} сузини {len(user_letter)} уринишда топдингиз!')
    
play()
# Out:
# авиалиния
# Men 9 хоналик су'з уйладим топа оласизми?
# ---------
# >>>b
# Bunday harf mavjud emas!
# ---------
# Шу вактгача топган харфларингиз b
# >>>и
# Bunday harf bor
# --и--и-и-
# Шу вактгача топган харфларингиз bи
# >>>в
# Bunday harf bor
# -ви--и-и-
# Шу вактгача топган харфларингиз bив
# >>>в
# Bunday harf avval kiritilgan!
# -ви--и-и-
# Шу вактгача топган харфларингиз bивв
# >>>а
# Bunday harf bor
# авиа-и-и-
# Шу вактгача топган харфларингиз bивва
# >>>ь
# Bunday harf mavjud emas!
# авиа-и-и-
# Шу вактгача топган харфларингиз bивваь
# >>>л
# Bunday harf bor
# авиали-и-
# Шу вактгача топган харфларингиз bивваьл
# >>>н
# Bunday harf bor
# авиалини-
# Шу вактгача топган харфларингиз bивваьлн
# >>>я
# Bunday harf bor
# Табриклайман сиз авиалиния сузини 9 уринишда топдингиз!
